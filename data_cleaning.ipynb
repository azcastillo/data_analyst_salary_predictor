# %% [markdown]
# # Data Cleaning Notebook

# %% [markdown]
# The following notebook is used to clean the data for the DataAnalyst.csv file. Many of the techniques are similar to those used by Ken Jee in his tutorial. I found them to be extremely useful, clear, and effective which is why I wanted to use them here. I created and used different features than him, as well as analyzed more nuanced aspects of the data analyst position, such as degrees required and how they relate to the average salary.

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('DataAnalyst.csv')

# %%
df.sample(20)
# Out:
#       Unnamed: 0                                        Job Title  \
# 2005        2005                                     Data Analyst
# 769          769                                     Data Analyst
# 69            69                           Data/Reporting Analyst
# 1433        1433                          Data Management Analyst
# 317          317  Data Management, Firmwide Data Quality, Analyst
# 696          696                     Music Copyright Data Analyst
# 1260        1260                              Junior Data Analyst
# 2058        2058     Data and Policy Analyst - Writer/Coordinator
# 695          695                        Data Analyst-HEDIS & Star
# 1828        1828                              Senior Data Analyst
# 1367        1367             RAPD Risk Platforms & Data - Analyst
# 1577        1577     Data Analyst - Bilingual English and Italian
# 1373        1373                              Senior Data Analyst
# 1208        1208                                     Data Analyst
# 1780        1780                                     Data Analyst
# 712          712     QM DATA ANALYST II, WHITTIER, FULL TIME DAYS
# 150          150                                     Data Analyst
# 166          166           Senior Data Analyst - Health Economist
# 907          907                                  Data Analyst II
# 748          748                                     Data Analyst
#
#                    Salary Estimate  \
# 2005   $65K-$120K (Glassdoor est.)
# 769     $73K-$82K (Glassdoor est.)
# 69      $51K-$88K (Glassdoor est.)
# 1433    $48K-$88K (Glassdoor est.)
# 317     $42K-$74K (Glassdoor est.)
# 696   $113K-$132K (Glassdoor est.)
# 1260   $76K-$122K (Glassdoor est.)
# 2058    $47K-$74K (Glassdoor est.)
# 695   $113K-$132K (Glassdoor est.)
# 1828    $54K-$75K (Glassdoor est.)
# 1367    $30K-$53K (Glassdoor est.)
# 1577    $51K-$93K (Glassdoor est.)
# 1373    $41K-$86K (Glassdoor est.)
# 1208    $37K-$68K (Glassdoor est.)
# 1780    $28K-$52K (Glassdoor est.)
# 712   $113K-$132K (Glassdoor est.)
# 150     $43K-$76K (Glassdoor est.)
# 166     $43K-$76K (Glassdoor est.)
# 907     $29K-$38K (Glassdoor est.)
# 748     $60K-$66K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2005  Job Description\nEssential Functions:\n\n• Des...     2.5
# 769   Job Description\nJob description\n\n• Interpre...     5.0
# 69    Position Summary\nA data management/analyst wh...     3.9
# 1433  Principal AccountabilityReporting to the Manag...     3.2
# 317   About the Chief Data Office\n\nThe FDM Data Qu...     3.9
# 696   Music Copyright Data Analyst position availabl...     3.3
# 1260  Job Description\nJob description\nInterpret da...     5.0
# 2058  Job Description\n\nAt Acumen, LLC / The SPHERE...     3.2
# 695   Data Analyst– HEDIS& Star\nLong Beach, CA\nFul...     3.2
# 1828  Req ID: 94674\n\nNTT DATA Services strives to ...     3.4
# 1367  MORE ABOUT THIS JOB\n\nENGINEERING\n\nWhat We ...     4.0
# 1577  Employer: Vaco (Onsite Vendor for client)\nPos...     3.3
# 1373  **This position is located in Irvine, CA. Relo...     4.5
# 1208  Huntington Ingalls Industries is America's lar...     3.7
# 1780  We are currently accepting resumes for a Data ...     4.5
# 712   PIH Health is a nonprofit, regional healthcare...     3.6
# 150   NYU Grossman School of Medicine is one of the ...     4.0
# 166   Job Description\nAbout Data Analytics at Veric...     2.9
# 907   Home » New Job from Competentia\nData Analyst ...     4.9
# 748   Address:111 W Monroe - 115 S LaSalleJob Family...     3.7
#
#                                Company Name            Location  \
# 2005                          Enclipse\n2.5         Oakland, CA
# 769   Staffigo Technical Services, LLC\n5.0         Chicago, IL
# 69                        Diverse Lynx\n3.9        New York, NY
# 1433    Community Hospital Corporation\n3.2           Plano, TX
# 317                        J.P. Morgan\n3.9          Newark, NJ
# 696                           AppleOne\n3.3  Woodland Hills, CA
# 1260  Staffigo Technical Services, LLC\n5.0       San Diego, CA
# 2058                            Acumen\n3.2      Burlingame, CA
# 695                   SCAN Health Plan\n3.2      Long Beach, CA
# 1828              NTT DATA Corporation\n3.4       Charlotte, NC
# 1367                     Goldman Sachs\n4.0          Dallas, TX
# 1577                              Vaco\n3.3       Palo Alto, CA
# 1373                      Mobilityware\n4.5          Dallas, TX
# 1208     Huntington Ingalls Industries\n3.7     San Antonio, TX
# 1780         UNICON International, Inc\n4.5        Columbus, OH
# 712                         PIH Health\n3.6        Whittier, CA
# 150                 NYU Langone Health\n4.0        New York, NY
# 166                           Vericred\n2.9        New York, NY
# 907                Competentia Holding\n4.9         Houston, TX
# 748                BMO Financial Group\n3.7         Chicago, IL
#
#            Headquarters                     Size  Founded  \
# 2005    Minneapolis, MN      51 to 200 employees       -1
# 769       Woodridge, IL      51 to 200 employees     2008
# 69        Princeton, NJ    501 to 1000 employees     2002
# 1433          Plano, TX   1001 to 5000 employees     1996
# 317        New York, NY         10000+ employees     1799
# 696        Glendale, CA   1001 to 5000 employees     1964
# 1260      Woodridge, IL      51 to 200 employees     2008
# 2058     Burlingame, CA     201 to 500 employees     1996
# 695      Long Beach, CA    501 to 1000 employees     1977
# 1828       Tokyo, Japan         10000+ employees     1967
# 1367       New York, NY         10000+ employees     1869
# 1577      Brentwood, TN    501 to 1000 employees     2002
# 1373         Irvine, CA      51 to 200 employees     1990
# 1208   Newport News, VA         10000+ employees     2011
# 1780    Los Angeles, CA        1 to 50 employees       -1
# 712        Whittier, CA  5001 to 10000 employees     1959
# 150        New York, NY         10000+ employees     1841
# 166        New York, NY        1 to 50 employees     2015
# 907   Stavanger, Norway    501 to 1000 employees       -1
# 748     Toronto, Canada         10000+ employees     1817
#
#            Type of ownership                               Industry  \
# 2005       Company - Private                            IT Services
# 769        Company - Private                            IT Services
# 69         Company - Private                            IT Services
# 1433       Company - Private       Health Care Services & Hospitals
# 317         Company - Public  Investment Banking & Asset Management
# 696        Company - Private                 Staffing & Outsourcing
# 1260       Company - Private                            IT Services
# 2058       Company - Private                       Federal Agencies
# 695   Nonprofit Organization                     Insurance Carriers
# 1828        Company - Public                            IT Services
# 1367        Company - Public  Investment Banking & Asset Management
# 1577       Company - Private                             Consulting
# 1373       Company - Private                            Video Games
# 1208        Company - Public                    Aerospace & Defense
# 1780       Company - Private                                     -1
# 712   Nonprofit Organization       Health Care Services & Hospitals
# 150                 Hospital       Health Care Services & Hospitals
# 166        Company - Private                               Internet
# 907        Company - Private                                     -1
# 748         Company - Public                  Banks & Credit Unions
#
#                       Sector                           Revenue  \
# 2005  Information Technology           $5 to $10 million (USD)
# 769   Information Technology         $50 to $100 million (USD)
# 69    Information Technology        $100 to $500 million (USD)
# 1433             Health Care          Unknown / Non-Applicable
# 317                  Finance                $10+ billion (USD)
# 696        Business Services            $1 to $2 billion (USD)
# 1260  Information Technology         $50 to $100 million (USD)
# 2058              Government          $10 to $25 million (USD)
# 695                Insurance            $2 to $5 billion (USD)
# 1828  Information Technology                $10+ billion (USD)
# 1367                 Finance                $10+ billion (USD)
# 1577       Business Services  $500 million to $1 billion (USD)
# 1373                   Media          Unknown / Non-Applicable
# 1208     Aerospace & Defense           $5 to $10 billion (USD)
# 1780                      -1            $1 to $5 million (USD)
# 712              Health Care            $1 to $2 billion (USD)
# 150              Health Care           $5 to $10 billion (USD)
# 166   Information Technology          Unknown / Non-Applicable
# 907                       -1          Unknown / Non-Applicable
# 748                  Finance                $10+ billion (USD)
#
#                                           Competitors Easy Apply
# 2005                              Accenture, Deloitte         -1
# 769                                                -1         -1
# 69                                                 -1         -1
# 1433                                               -1         -1
# 317                                                -1         -1
# 696                                   Kelly, Manpower         -1
# 1260                                               -1         -1
# 2058                                           Acumen         -1
# 695                                                -1         -1
# 1828                   Capgemini, Accenture, Deloitte         -1
# 1367       J.P. Morgan, Merrill Lynch, Morgan Stanley         -1
# 1577                                               -1         -1
# 1373                                               -1         -1
# 1208                General Dynamics, Lockheed Martin         -1
# 1780                                               -1         -1
# 712    Adventist Health, Providence Health & Services         -1
# 150   NewYork-Presbyterian Hospital, Northwell Health         -1
# 166                                                -1         -1
# 907                                                -1         -1
# 748                                     CIBC, RBC, TD         -1

# %%
#get more succinct job titles. Idea for such a function taken from Ken Jee's data science 
#tutorial 
def job_simplifier(title):
    if 'data analyst' in title.lower() or 'analytics' in title.lower():
        return 'data analyst'
    elif 'data scientist' in title.lower() or 'data science analyst' in title.lower() or 'data science' in title.lower():
        return 'data scientist'
    elif 'business analyst' in title.lower():
        return 'business analyst'
    elif 'data management' in title.lower():
        return 'data management'
    elif 'data warehouse' in title.lower():
        return 'data warehouse enginner'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'security analyst' in title.lower():
        return 'data security analyst'
    elif 'risk' in title.lower():
        return 'risk analyst'
    else: 
        return 'other'

# %%
#Idea for such a function taken from Ken Jee's data science 
#tutorial
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['simplified_title']=df['Job Title'].apply(job_simplifier)
df.simplified_title.value_counts()
# Out:
# data analyst               1708
# other                       363
# business analyst             50
# data management              39
# data scientist               38
# data warehouse enginner      25
# data security analyst        12
# data engineer                10
# risk analyst                  8
# Name: simplified_title, dtype: int64

# %%
#get the junior and senior titles 
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        1699
# senior     481
# jr          73
# Name: seniority, dtype: int64

# %%
pd.DataFrame(df.loc[df.simplified_title=='other']['Job Title'].value_counts())
# Out:
#                                           Job Title
# Data Quality Analyst                             17
# Data Governance Analyst                          16
# Data Reporting Analyst                           13
# NY Healthcare Data/Reporting Analyst              5
# Healthcare Data/Reporting Analyst                 4
# ...                                             ...
# Lead Analyst, Data Mgmt / Quant Analysis          1
# Data Systems Analyst III                          1
# Data/Business Solutions Analyst - Jr              1
# Data Quality Control Analyst                      1
# Business Systems Analyst-Data                     1
#
# [262 rows x 1 columns]

# %%
string='Senior Data Science Analyst'
'data analyst' in string.lower()
# Out:
# False

# %%
#get the average salary 
#looking at the salary ranges for the jobs 
df['Salary Estimate'].value_counts()
# Out:
# $42K-$76K (Glassdoor est.)    57
# $41K-$78K (Glassdoor est.)    57
# $50K-$86K (Glassdoor est.)    41
# $35K-$67K (Glassdoor est.)    33
# $43K-$76K (Glassdoor est.)    31
#                               ..
# $47K-$81K (Glassdoor est.)     3
# $43K-$77K (Glassdoor est.)     3
# $36K-$67K (Glassdoor est.)     3
# $57K-$70K (Glassdoor est.)     2
# -1                             1
# Name: Salary Estimate, Length: 90, dtype: int64

# %%
#no hourly jobs 
df.loc[df['Salary Estimate']=='per hour']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply, simplified_title, seniority]
# Index: []

# %%
#no employer provided salaries 
df.loc[df['Salary Estimate']=='employer provided salary']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, Competitors, Easy Apply, simplified_title, seniority]
# Index: []

# %%
#want to get companies that only have numeric salaries 
df=df[df['Salary Estimate']!='-1']
df['Salary Estimate'].value_counts()
# Out:
# $42K-$76K (Glassdoor est.)    57
# $41K-$78K (Glassdoor est.)    57
# $50K-$86K (Glassdoor est.)    41
# $35K-$67K (Glassdoor est.)    33
# $43K-$76K (Glassdoor est.)    31
#                               ..
# $42K-$63K (Glassdoor est.)     4
# $47K-$81K (Glassdoor est.)     3
# $43K-$77K (Glassdoor est.)     3
# $36K-$67K (Glassdoor est.)     3
# $57K-$70K (Glassdoor est.)     2
# Name: Salary Estimate, Length: 89, dtype: int64

# %%
#parsing out the salary to get the average 

#just getting the salary range from the text inside the 'Salary Estimate' column
df['salary_range']=df['Salary Estimate'].apply(lambda x: x.split('(')[0])

#get the 'K' values out to find the average 
df['salary_range']=df['salary_range'].apply(lambda x: x.replace('K', ""))

#get the minimum salary 
df['min_salary']=df['salary_range'].apply(lambda x: x.split('-')[0]).apply(lambda x: x.replace('$', ''))
df['min_salary']=df['min_salary'].apply(lambda x: int(x))

#get the maximum salary 
df['max_salary']=df['salary_range'].apply(lambda x: x.split('-')[1]).apply(lambda x: x.replace('$', ''))
df['max_salary']=df['max_salary'].apply(lambda x: int(x))

#get the average salary column (this will be the target variable)
df['avg_salary']=(df['max_salary']+df['min_salary'])/2

# %%
#get age of company
df['company_age']=df.Founded.apply(lambda x: x if x<1 else 2021-x)

# %%
#get name of company 
df['company_name']=df.apply(lambda x: x['Company Name'] if x.Rating<0 else x['Company Name'][:-4], axis=1)

# %%
#more information on the location of each position

#get state of company
df['state']=df.Location.apply(lambda x: x.split(',')[1])
#city of company
df['city']=df.Location.apply(lambda x: x.split(',')[0])
#state or country of headquarters
df['headquarters_state']=df.Headquarters.apply(lambda x: -1 if x=='-1' else x.split(",")[1])
#position is in the same state as headquarter
df['same_location']=df.apply(lambda x: 1 if x.state==x.headquarters_state else 0, axis=1)

# %%
#change 'Arapahoe' to Colorado since they county resides there
df['state']=df.state.apply(lambda x: ' CO' if x==' Arapahoe' else x )

# %%
df.state.value_counts()
# Out:
#  CA    626
#  TX    394
#  NY    345
#  IL    164
#  PA    114
#  AZ     97
#  CO     96
#  NC     90
#  NJ     86
#  WA     53
#  VA     48
#  OH     35
#  UT     33
#  FL     27
#  IN     23
#  DE     11
#  GA      4
#  KS      3
#  SC      3
# Name: state, dtype: int64

# %%
df.loc[df.state==' CO']
# Out:
#       Unnamed: 0                                          Job Title  \
# 2157        2157                          Data Analyst - Denver, CO
# 2158        2158                          Inside Sales Data Analyst
# 2159        2159                                       Data Analyst
# 2160        2160            Senior Data Analyst, Sales Compensation
# 2161        2161                                       Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 2157   $57K-$67K (Glassdoor est.)
# 2158   $57K-$67K (Glassdoor est.)
# 2159   $57K-$67K (Glassdoor est.)
# 2160   $57K-$67K (Glassdoor est.)
# 2161   $57K-$67K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2157  ­­As a member of the company’s information tec...     3.8
# 2158  Job Requisition ID #\n20WD40934\n\nPosition Ov...     4.0
# 2159  Position Type: Permanent\n\nCompensation: Comm...     3.6
# 2160  Because you belong at Twilio\n\nThe Who, What,...     4.0
# 2161  The Data Analyst is responsible for the all da...     3.8
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                           Company Name        Location       Headquarters  \
# 2157                     CoreSite\n3.8      Denver, CO         Denver, CO
# 2158                     Autodesk\n4.0      Denver, CO     San Rafael, CA
# 2159            Dire Wolf Digital\n3.6      Denver, CO         Denver, CO
# 2160                       Twilio\n4.0      Denver, CO  San Francisco, CA
# 2161                BridgeView IT\n3.8      Denver, CO         Denver, CO
# ...                                ...             ...                ...
# 2248                Avacend, Inc.\n2.5      Denver, CO     Alpharetta, GA
# 2249            Arrow Electronics\n2.9  Centennial, CO     Centennial, CO
# 2250                          Spiceorb      Denver, CO                 -1
# 2251  Contingent Network Services\n3.1  Centennial, CO   West Chester, OH
# 2252                   SCL Health\n3.4  Broomfield, CO     Broomfield, CO
#
#                          Size  Founded  ... salary_range min_salary  \
# 2157     201 to 500 employees     2001  ...     $57-$67          57
# 2158  5001 to 10000 employees     1982  ...     $57-$67          57
# 2159      51 to 200 employees     2010  ...     $57-$67          57
# 2160   1001 to 5000 employees     2008  ...     $57-$67          57
# 2161        1 to 50 employees     2005  ...     $57-$67          57
# ...                       ...      ...  ...          ...        ...
# 2248      51 to 200 employees       -1  ...    $78-$104          78
# 2249         10000+ employees     1935  ...    $78-$104          78
# 2250                       -1       -1  ...    $78-$104          78
# 2251     201 to 500 employees     1984  ...    $78-$104          78
# 2252         10000+ employees     1864  ...    $78-$104          78
#
#      max_salary avg_salary company_age                 company_name state  \
# 2157         67       62.0          20                     CoreSite    CO
# 2158         67       62.0          39                     Autodesk    CO
# 2159         67       62.0          11            Dire Wolf Digital    CO
# 2160         67       62.0          13                       Twilio    CO
# 2161         67       62.0          16                BridgeView IT    CO
# ...         ...        ...         ...                          ...   ...
# 2248        104       91.0          -1                Avacend, Inc.    CO
# 2249        104       91.0          86            Arrow Electronics    CO
# 2250        104       91.0          -1                     Spiceorb    CO
# 2251        104       91.0          37  Contingent Network Services    CO
# 2252        104       91.0         157                   SCL Health    CO
#
#             city headquarters_state  same_location
# 2157      Denver                 CO              1
# 2158      Denver                 CA              0
# 2159      Denver                 CO              1
# 2160      Denver                 CA              0
# 2161      Denver                 CO              1
# ...          ...                ...            ...
# 2248      Denver                 GA              0
# 2249  Centennial                 CO              1
# 2250      Denver                 -1              0
# 2251  Centennial                 OH              0
# 2252  Broomfield                 CO              1
#
# [96 rows x 28 columns]

# %%
df.sample(10)
# Out:
#       Unnamed: 0                                          Job Title  \
# 789          789                            Data Operations Analyst
# 1550        1550                                Master Data Analyst
# 1640        1640                                Junior Data Analyst
# 548          548                   Senior Data Intelligence Analyst
# 2091        2091                                Data Analyst Junior
# 907          907                                    Data Analyst II
# 1781        1781  JPSC-7975 - Data Analyst Lead- Columbus, OH (L...
# 1731        1731  Assistant Vice President, Anti Financial Crime...
# 457          457                   Tactical Data Link (TDL) Analyst
# 22            22                     Data Analyst - Intex Developer
#
#                   Salary Estimate  \
# 789    $67K-$92K (Glassdoor est.)
# 1550  $69K-$127K (Glassdoor est.)
# 1640   $42K-$76K (Glassdoor est.)
# 548    $37K-$70K (Glassdoor est.)
# 2091   $34K-$61K (Glassdoor est.)
# 907    $29K-$38K (Glassdoor est.)
# 1781   $28K-$52K (Glassdoor est.)
# 1731   $40K-$72K (Glassdoor est.)
# 457    $43K-$69K (Glassdoor est.)
# 22     $37K-$66K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 789   Overview\n\nPDI is seeking a Data Operations A...     3.2
# 1550  Title Master Data AnalystStart Date Immediatel...     4.7
# 1640  Job Description\nThe Details:\n\nData drives s...     2.6
# 548   Grow your career at Cedars-Sinai!\n\n\nCome jo...     3.9
# 2091  Job Description\nJob description\nInterpret da...     5.0
# 907   Home » New Job from Competentia\nData Analyst ...     4.9
# 1781  Overview\n\nRole: Data Analyst Lead – Informat...     4.5
# 1731  Job Description\n\nJob Description:\n\nDB USA ...     3.5
# 457   Working at USfalcon is about providing excepti...     4.3
# 22    Data Analyst - Intex Developer\n\n\nNew York\n...     3.3
#
#                                Company Name          Location  \
# 789                       PDI Software\n3.2       Chicago, IL
# 1550                         Method360\n4.7      San Jose, CA
# 1640                          Assembly\n2.6        Austin, TX
# 548                       Cedars-Sinai\n3.9   Los Angeles, CA
# 2091  Staffigo Technical Services, LLC\n5.0  Indianapolis, IN
# 907                Competentia Holding\n4.9       Houston, TX
# 1781        Avani Technology Solutions\n4.5      Columbus, OH
# 1731                     Deutsche Bank\n3.5  Jacksonville, FL
# 457                           USfalcon\n4.3       Hampton, VA
# 22                     Macquarie Group\n3.3      New York, NY
#
#                     Headquarters                   Size  Founded  ...  \
# 789                  Atlanta, GA  501 to 1000 employees     1983  ...
# 1550           San Francisco, CA    51 to 200 employees     2000  ...
# 1640                New York, NY   201 to 500 employees     2014  ...
# 548              Los Angeles, CA       10000+ employees     1902  ...
# 2091               Woodridge, IL    51 to 200 employees     2008  ...
# 907            Stavanger, Norway  501 to 1000 employees       -1  ...
# 1781               Rochester, NY  501 to 1000 employees     2008  ...
# 1731  Frankfurt am Main, Germany       10000+ employees     1870  ...
# 457                     Cary, NC   201 to 500 employees     1984  ...
# 22             Sydney, Australia       10000+ employees     1969  ...
#
#      salary_range min_salary max_salary avg_salary company_age  \
# 789      $67-$92          67         92       79.5          38
# 1550    $69-$127          69        127       98.0          21
# 1640     $42-$76          42         76       59.0           7
# 548      $37-$70          37         70       53.5         119
# 2091     $34-$61          34         61       47.5          13
# 907      $29-$38          29         38       33.5          -1
# 1781     $28-$52          28         52       40.0          13
# 1731     $40-$72          40         72       56.0         151
# 457      $43-$69          43         69       56.0          37
# 22       $37-$66          37         66       51.5          52
#
#                           company_name state          city headquarters_state  \
# 789                       PDI Software    IL       Chicago                 GA
# 1550                         Method360    CA      San Jose                 CA
# 1640                          Assembly    TX        Austin                 NY
# 548                       Cedars-Sinai    CA   Los Angeles                 CA
# 2091  Staffigo Technical Services, LLC    IN  Indianapolis                 IL
# 907                Competentia Holding    TX       Houston             Norway
# 1781        Avani Technology Solutions    OH      Columbus                 NY
# 1731                     Deutsche Bank    FL  Jacksonville            Germany
# 457                           USfalcon    VA       Hampton                 NC
# 22                     Macquarie Group    NY      New York          Australia
#
#       same_location
# 789               0
# 1550              1
# 1640              0
# 548               1
# 2091              0
# 907               0
# 1781              0
# 1731              0
# 457               0
# 22                0
#
# [10 rows x 28 columns]

# %%
#get average size of company 
df.Size.unique()
# Out:
# array(['201 to 500 employees', '10000+ employees',
#        '1001 to 5000 employees', '501 to 1000 employees',
#        '5001 to 10000 employees', '1 to 50 employees',
#        '51 to 200 employees', 'Unknown', '-1'], dtype=object)

# %%
df.Size.value_counts()
# Out:
# 51 to 200 employees        420
# 10000+ employees           375
# 1001 to 5000 employees     348
# 1 to 50 employees          347
# 201 to 500 employees       249
# 501 to 1000 employees      211
# -1                         163
# 5001 to 10000 employees     97
# Unknown                     42
# Name: Size, dtype: int64

# %%
#get size range of company 
df['size_range']=df.Size.apply(lambda x: x if x=='Unknown' or x=='-1' else x.split('employees')[0])

# %%
#get minimum size of company
df['min_size']=df.size_range.apply(lambda x: x if x=='Unknown' or x=='-1' or x=='10000+ ' else x.split('to')[0])

df['min_size']=df.min_size.apply(lambda x: 10000 if '+ ' in x else x)

df['min_size']=df.min_size.apply(lambda x: 0 if x=='-1' or x=='Unknown' else x).apply(lambda x: int(x))

# %%
#get maximum size of company
df['max_size']=df.size_range.apply(lambda x: x if x=='Unknown' or x=='-1' or x=='10000+ ' else x.split('to')[1])

#setting the maximum size of a company to 300000
df['max_size']=df.max_size.apply(lambda x: 30000 if '10000+' in x else x)

df['max_size']=df.max_size.apply(lambda x: 0 if x=='-1' or x=='Unknown' else x).apply(lambda x: int(x))

# %%
#get the average size of the company 
df['avg_size']=(df.max_size+df.min_size)/2

# %%
#get mean median size of company and replace the 0's with it. 
#that way we are not prone to outliers 
median_size=df.loc[df.avg_size!=0].avg_size.median()

df['avg_size']=df.avg_size.replace(0, median_size).replace(0.0, median_size)

# %%
#python in description
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df.python.value_counts()
# Out:
# 0    1615
# 1     637
# Name: python, dtype: int64

# %%
#sql in description
df['sql'] = df['Job Description'].apply(lambda x: 1 if 'SQL' in x else 0)
df.sql.value_counts()
# Out:
# 1    1378
# 0     874
# Name: sql, dtype: int64

# %%
#Excel in description
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.excel.value_counts()
# Out:
# 1    1353
# 0     899
# Name: excel, dtype: int64

# %%
#R in description
df['R'] = df['Job Description'].apply(lambda x: 1 if 'R' in x else 0)
df.R.value_counts()
# Out:
# 1    2106
# 0     146
# Name: R, dtype: int64

# %%
#deep learning in description
df['deep_learning'] = df['Job Description'].apply(lambda x: 1 if 'Deep Learning' in x or 'deep learning' in x 
                                                  or 'Tensorflow' in x or 'Keras' in x 
                                                  or 'tensorflow' in x or 'keras' in x
                                                  or 'neural nets' in x else 0)
df.deep_learning.value_counts()
# Out:
# 0    2241
# 1      11
# Name: deep_learning, dtype: int64

# %%
#PhD in description
df['PhD'] = df['Job Description'].apply(lambda x: 1 if 'PhD' in x or 'phd' in x or 'Ph.D' in x 
                                        or 'Doctor of Philosophy' in x or 'Ph.D' in x else 0)
df.PhD.value_counts()
# Out:
# 0    2203
# 1      49
# Name: PhD, dtype: int64

# %%
#bachelor degree in description
df['bachelor'] = df['Job Description'].apply(lambda x: 1 if 'bachelor' in x or 'bachelors' in x or "bachelor's" in x 
                                             or 'Bachelor' in x or 'Bachelors' in x or "Bachelor's" else 0)
df.bachelor.value_counts()
#All want
# Out:
# 1    2252
# Name: bachelor, dtype: int64

# %%
#masters degree in description
df['masters'] = df['Job Description'].apply(lambda x: 1 if 'masters' in x or "master's" in x 
                                            or "Masters" in x or "Master's" in x or 'MS' in x 
                                            or 'M.S' in x or 'MA' in x or 'M.A' in x else 0)
df.masters.value_counts()
# Out:
# 0    1430
# 1     822
# Name: masters, dtype: int64

# %%
#Power BI in description
df['power_bi'] = df['Job Description'].apply(lambda x: 1 if 'Power BI' in x or 'power BI' in x or 'Power bi' in x
                                             or 'power BI' in x else 0)
df.power_bi.value_counts()
# Out:
# 0    2072
# 1     180
# Name: power_bi, dtype: int64

# %%
#Power BI in description
df['tableau'] = df['Job Description'].apply(lambda x: 1 if 'tableau' in x or 'Tableau' in x else 0)
df.tableau.value_counts()
# Out:
# 0    1632
# 1     620
# Name: tableau, dtype: int64

# %%
#Problem Solver in description
df['prob_solver'] = df['Job Description'].apply(lambda x: 1 if 'problem solver' in x.lower() else 0)
df.prob_solver.value_counts()
# Out:
# 0    2214
# 1      38
# Name: prob_solver, dtype: int64

# %%
#Problem Solver in description
df['critical_thinker'] = df['Job Description'].apply(lambda x: 1 if 'critical thinker' in x.lower() else 0)
df.critical_thinker.value_counts()
# Out:
# 0    2234
# 1      18
# Name: critical_thinker, dtype: int64

# %%
df.sample(10)
# Out:
#       Unnamed: 0                                     Job Title  \
# 1938        1938                                  Data Analyst
# 576          576                           Senior Data Analyst
# 716          716                  Radar Telemetry Data Analyst
# 738          738                         Business Data Analyst
# 876          876         Analyst IV Systems - Data Engineering
# 1836        1836  Data Analyst/ Python with Banking Experience
# 1678        1678                               Data Analyst II
# 975          975                    Data Warehouse Analyst III
# 1817        1817                                  Data Analyst
# 750          750                                  Data Analyst
#
#                   Salary Estimate  \
# 1938  $99K-$178K (Glassdoor est.)
# 576   $57K-$103K (Glassdoor est.)
# 716    $42K-$63K (Glassdoor est.)
# 738    $60K-$66K (Glassdoor est.)
# 876    $68K-$87K (Glassdoor est.)
# 1836   $54K-$75K (Glassdoor est.)
# 1678  $53K-$104K (Glassdoor est.)
# 975    $53K-$94K (Glassdoor est.)
# 1817   $50K-$86K (Glassdoor est.)
# 750    $73K-$82K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 1938  Voleon is a technology company that applies st...     4.6
# 576   **This position is located in Irvine, CA. Relo...     4.5
# 716   Job Description\nOur prestigious client is loo...    -1.0
# 738   Work. Serve. Thrive.Imagine a place where your...     3.3
# 876   About Retail Business Services\nRetail Busines...     3.9
# 1836  Title Sr Data Analyst with Python Location Cha...     2.9
# 1678  Professional\n\nPosition Purpose:\nAnalyze hea...     3.3
# 975   Rethink what’s possible with SwitchThink! Swit...     3.2
# 1817  Hello Associates,\n\n*****Greetings from Conch...     4.6
# 750   Senior AWS Developer\n\nUST Global is looking ...     4.2
#
#                             Company Name         Location     Headquarters  \
# 1938               The Voleon Group\n4.6     Berkeley, CA     Berkeley, CA
# 576                    Mobilityware\n4.5  Los Angeles, CA       Irvine, CA
# 716                       TopTalentFetch      Anaheim, CA               -1
# 738                 Feeding America\n3.3      Chicago, IL      Chicago, IL
# 876   Retail Business Services, LLC\n3.9      Chicago, IL    Salisbury, NC
# 1836                 Shimento, Inc.\n2.9    Charlotte, NC      Benicia, CA
# 1678            Centene Corporation\n3.3       Austin, TX  Saint Louis, MO
# 975   Desert Financial Credit Union\n3.2      Phoenix, AZ      Phoenix, AZ
# 1817        Conch Technologies, Inc\n4.6    Charlotte, NC      Memphis, TN
# 750                      UST Global\n4.2      Chicago, IL  Aliso Viejo, CA
#
#                         Size  Founded  ... excel  R deep_learning PhD  \
# 1938     51 to 200 employees     2007  ...     0  1             0   0
# 576      51 to 200 employees     1990  ...     0  1             0   0
# 716                       -1       -1  ...     0  1             0   0
# 738      51 to 200 employees     1979  ...     1  1             0   0
# 876   1001 to 5000 employees       -1  ...     1  1             0   0
# 1836       1 to 50 employees       -1  ...     1  1             0   0
# 1678        10000+ employees     1984  ...     1  1             0   0
# 975   1001 to 5000 employees     1939  ...     0  1             0   0
# 1817     51 to 200 employees       -1  ...     0  1             0   0
# 750         10000+ employees     1999  ...     1  1             0   0
#
#      bachelor masters power_bi tableau prob_solver  critical_thinker
# 1938        1       0        0       0           0                 1
# 576         1       1        0       0           0                 0
# 716         1       0        0       0           0                 0
# 738         1       1        0       1           0                 0
# 876         1       0        0       0           0                 0
# 1836        1       1        0       0           0                 0
# 1678        1       1        0       0           0                 0
# 975         1       0        1       0           0                 0
# 1817        1       0        0       0           0                 0
# 750         1       1        0       0           0                 0
#
# [10 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'simplified_title', 'seniority', 'salary_range',
#        'min_salary', 'max_salary', 'avg_salary', 'company_age', 'company_name',
#        'state', 'city', 'headquarters_state', 'same_location', 'size_range',
#        'min_size', 'max_size', 'avg_size', 'python', 'sql', 'excel', 'R',
#        'deep_learning', 'PhD', 'bachelor', 'masters', 'power_bi', 'tableau',
#        'prob_solver', 'critical_thinker'],
#       dtype='object')

# %%
df_final=df.drop('Unnamed: 0', axis=1)
df_final.sample(10)
# Out:
#                                      Job Title              Salary Estimate  \
# 1180           Data Engineer/Reporting Analyst  $64K-$113K (Glassdoor est.)
# 340             Sr. Data Analyst, Retail Media  $77K-$132K (Glassdoor est.)
# 747               Data Analyst - IntelliScript   $60K-$66K (Glassdoor est.)
# 493           Data Analyst - Senior Consultant  $49K-$112K (Glassdoor est.)
# 1725                       Junior Data Analyst   $40K-$72K (Glassdoor est.)
# 815                               Data Analyst   $42K-$76K (Glassdoor est.)
# 2000                     Business Data Analyst  $65K-$120K (Glassdoor est.)
# 1628  Manager : Marketing Ops and Data Analyst  $63K-$116K (Glassdoor est.)
# 1499                              Data Analyst  $89K-$151K (Glassdoor est.)
# 928                           MDM Data Analyst   $47K-$76K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 1180  An emerging IoT technology company in Philadel...     1.6
# 340   Who we are\nCriteo (NASDAQ: CRTO) is the globa...     3.9
# 747   Role Description\n\nBy leveraging our relation...     3.8
# 493   OverviewGuidehouse is a leading management con...     3.4
# 1725  Job Description\nJob description\nInterpret da...     5.0
# 815   KellyMitchell matches the best IT and business...     3.6
# 2000  Job Title: Business Data Analyst\n\nLocation: ...     3.8
# 1628  In this role you will be a part of a project t...    -1.0
# 1499  We are hiring Data Analyst for our client in R...     5.0
# 928   Arthur Lawrence is urgently looking for MDM Da...     4.1
#
#                                Company Name           Location  \
# 1180        Management Decisions, Inc.\n1.6   Philadelphia, PA
# 340                             Criteo\n3.9       New York, NY
# 747                           Milliman\n3.8        Chicago, IL
# 493                         Guidehouse\n3.4        Norfolk, VA
# 1725  Staffigo Technical Services, LLC\n5.0   Jacksonville, FL
# 815               Kelly Mitchell Group\n3.6  Downers Grove, IL
# 2000                        VLink Inc.\n3.8  San Francisco, CA
# 1628                          Show Me Leads  Mountain View, CA
# 1499                      TechNet Inc.\n5.0       San Jose, CA
# 928                    Arthur Lawrence\n4.1        Houston, TX
#
#            Headquarters                     Size  Founded  Type of ownership  \
# 1180      Milwaukee, WI        1 to 50 employees       -1   Company - Public
# 340       Paris, France   1001 to 5000 employees     2005   Company - Public
# 747         Seattle, WA   1001 to 5000 employees     1947  Company - Private
# 493      Washington, DC  5001 to 10000 employees     2018  Company - Private
# 1725      Woodridge, IL      51 to 200 employees     2008  Company - Private
# 815     Saint Louis, MO   1001 to 5000 employees     1998  Company - Private
# 2000  South Windsor, CT     201 to 500 employees     2006  Company - Private
# 1628                 -1                       -1       -1                 -1
# 1499     Alpharetta, GA        1 to 50 employees       -1  Company - Private
# 928          Upland, CA     201 to 500 employees     2003  Company - Private
#
#       ... excel  R deep_learning PhD bachelor masters power_bi tableau  \
# 1180  ...     0  1             0   0        1       0        0       1
# 340   ...     0  1             0   0        1       0        0       0
# 747   ...     1  1             0   0        1       0        1       0
# 493   ...     0  1             0   0        1       0        0       0
# 1725  ...     1  1             0   0        1       1        0       0
# 815   ...     1  0             0   0        1       0        0       0
# 2000  ...     0  1             0   0        1       0        0       0
# 1628  ...     1  1             0   0        1       1        0       0
# 1499  ...     0  1             0   0        1       0        0       0
# 928   ...     0  1             0   0        1       0        0       0
#
#       prob_solver  critical_thinker
# 1180            0                 0
# 340             0                 0
# 747             0                 0
# 493             0                 0
# 1725            0                 0
# 815             0                 0
# 2000            0                 0
# 1628            0                 0
# 1499            0                 0
# 928             0                 0
#
# [10 rows x 43 columns]

# %%
#get a csv for eda 
df_final.to_csv('clean_salary_data.csv',index = False)
